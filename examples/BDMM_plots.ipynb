# %%
options(repr.plot.width=5, repr.plot.height=5)
library(rjson)

# %%
df <- fromJSON(file="BDMMTree_output.json")
plot(df$t, df$I[[1]], 's', col='blue', xlab='Time', ylab='I',
    main='Prevalence dynamics')
lines(df$t, df$I[[2]], 's', col='red')
lines(df$t, df$I[[3]], 's', col='darkgreen')
# Out:
# Plot with title “Prevalence dynamics”
